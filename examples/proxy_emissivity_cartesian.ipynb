# %%
# %load_ext autoreload
# %load_ext autotime
# %autoreload 2
# Out:
# time: 1.26 ms (started: 2025-05-31 16:39:32 +08:00)

# %%
import yt
import numpy as np
import matplotlib.pyplot as plt
from yt_tools.yt_cartesian_3D import cartesian_data
from astropy import units as u
from sunpy.visualization.colormaps import color_tables as ct
# Out:
# time: 7.6 s (started: 2025-05-31 16:42:53 +08:00)

# %%
instance = cartesian_data('./japan', sample_level=4)
proxy_emissivity = instance.proxy_emissivity(n_cores=50, sample_level=3, print_interval=1000)

aia_304_cmap = ct.aia_color_table(304*u.angstrom)
p = instance.show_proxy_emissivity(proxy_emissivity=proxy_emissivity, is_view3d=False, norm=[1,1,0], cmap=aia_304_cmap)
# Out:
# yt : [WARNING  ] 2025-05-31 16:45:18,459 'staggered' flag was found, but is currently ignored (unsupported)
# yt : [INFO     ] 2025-05-31 16:45:18,492 Parameters: current_time              = 0.0
# yt : [INFO     ] 2025-05-31 16:45:18,493 Parameters: domain_dimensions         = [60 60 60]
# yt : [INFO     ] 2025-05-31 16:45:18,495 Parameters: domain_left_edge          = [-3. -3.  0.]
# yt : [INFO     ] 2025-05-31 16:45:18,496 Parameters: domain_right_edge         = [3. 3. 6.]
# yt : [INFO     ] 2025-05-31 16:45:18,498 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2025-05-31 16:45:18,500 'staggered' flag was found, but is currently ignored (unsupported)
# yt : [INFO     ] 2025-05-31 16:45:18,534 Parameters: current_time              = 0.0
# yt : [INFO     ] 2025-05-31 16:45:18,535 Parameters: domain_dimensions         = [60 60 60]
# yt : [INFO     ] 2025-05-31 16:45:18,537 Parameters: domain_left_edge          = [-3. -3.  0.]
# ...
